# %%
import urllib2
from bs4 import BeautifulSoup
import pandas as pd

# %%
for i in range(1,55):
    url='''https://new.set.or.th/startup/browse/#?page={}'''.format(i)

# %%
url='''https://new.set.or.th/startup/browse/#?page={}'''.format(1)
content = urllib2.urlopen(url).read()
soup = BeautifulSoup(content, 'html.parser')
print soup.prettify()
# Out:
# <!DOCTYPE doctype html>
# <html ng-app="asipApp" prefix="og: http://ogp.me/ns#" scroll="">
#  <head>
#   <meta content="safari-fix" name="304Fix">
#    <meta charset="utf-8">
#     <meta content="IE=edge" http-equiv="X-UA-Compatible">
#      <meta content="width=device-width, initial-scale=1" name="viewport">
#       <meta content="800240250055674" property="fb:app_id"/>
#       <meta content="https://new.set.or.th/startup/browse/" property="og:url">
#        <meta content="
# Startup
# " property="og:title">
#         <meta content="new.set.or.th" property="og:site_name">
#          <meta content="
# Startup
# " name="twitter:title">
#           <meta content="https://new.set.or.th/startup/browse/" name="twitter:site">
#            <meta content="https://new.set.or.th/static/images/logo-startup.png" property="og:image"/>
#            <meta content="https://new.set.or.th/static/images/logo-startup.png" name="twitter:image"/>
#            <meta content="" property="og:description">
# ...

# %%
mydivs = soup.findAll("tr", { "class" : "party-item ng-scope" })

# %%
mydivs
# Out:
# []
